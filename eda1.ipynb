# %% [markdown]
# <a href="https://colab.research.google.com/github/Veera9014/practice-data-science-code/blob/main/eda1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df =pd.read_csv('BEML.csv')

# %%
df.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
df.shape
# Out:
# (1739, 8)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1739 entries, 0 to 1738
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1739 non-null   object
#  1   Open                  1739 non-null   float64
#  2   High                  1739 non-null   float64
#  3   Low                   1739 non-null   float64
#  4   Last                  1739 non-null   float64
#  5   Close                 1739 non-null   float64
#  6   Total Trade Quantity  1739 non-null   float64
#  7   Turnover (Lacs)       1739 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 108.8+ KB

# %%
df.isnull()
# Out:
#        Date   Open   High    Low   Last  Close  Total Trade Quantity  \
# 0     False  False  False  False  False  False                 False
# 1     False  False  False  False  False  False                 False
# 2     False  False  False  False  False  False                 False
# 3     False  False  False  False  False  False                 False
# 4     False  False  False  False  False  False                 False
# ...     ...    ...    ...    ...    ...    ...                   ...
# 1734  False  False  False  False  False  False                 False
# 1735  False  False  False  False  False  False                 False
# 1736  False  False  False  False  False  False                 False
# 1737  False  False  False  False  False  False                 False
# 1738  False  False  False  False  False  False                 False
#
#       Turnover (Lacs)
# 0               False
# 1               False
# 2               False
# 3               False
# ...

# %%
df.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1739.000000  1739.000000  1739.000000  1739.000000  1739.000000
# mean    700.233180   713.384704   686.280276   698.413370   698.435221
# std     358.658024   364.165083   351.554420   357.358712   357.429870
# min     129.300000   133.500000   106.000000   128.900000   129.150000
# 25%     371.025000   379.300000   367.525000   370.550000   370.650000
# 50%     685.000000   699.800000   666.750000   683.000000   682.150000
# 75%    1012.000000  1027.800000   997.000000  1011.200000  1010.550000
# max    1569.800000  1612.000000  1540.250000  1555.850000  1558.500000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.739000e+03      1739.000000
# mean           2.352309e+05      1682.773985
# std            3.561114e+05      2705.430289
# min            2.441000e+03        16.130000
# 25%            5.878150e+04       263.160000
# 50%            1.282050e+05       678.090000
# ...

# %%
data1=df.copy()

# %%
data1['Last']=pd.to_numeric(data1['Last'],errors='coerce')
data1['High']=pd.to_numeric(data1['High'],errors='coerce')
data1['Last']=pd.to_numeric(data1['Last'],errors='coerce')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1739 entries, 0 to 1738
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1739 non-null   object
#  1   Open                  1739 non-null   float64
#  2   High                  1739 non-null   float64
#  3   Low                   1739 non-null   float64
#  4   Last                  1739 non-null   float64
#  5   Close                 1739 non-null   float64
#  6   Total Trade Quantity  1739 non-null   float64
#  7   Turnover (Lacs)       1739 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 108.8+ KB

# %%
data1[data1['Last']==data1['Last']]
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
data1.drop('Last',axis=1,inplace=False)
# Out:
#             Date     Open     High      Low    Close  Total Trade Quantity  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1135.60              101651.0
# 1     2010-01-05  1146.80  1149.00  1128.75  1134.60               59504.0
# 2     2010-01-06  1140.00  1164.25  1130.05  1139.60              128908.0
# 3     2010-01-07  1142.00  1159.40  1119.20  1144.15              117871.0
# 4     2010-01-08  1156.00  1172.00  1140.00  1144.05              170063.0
# ...          ...      ...      ...      ...      ...                   ...
# 1734  2016-12-26   965.00   965.05   935.00   950.25              398696.0
# 1735  2016-12-27   960.70   989.00   952.35   975.70              808561.0
# 1736  2016-12-28   980.75   985.00   970.15   974.40              367041.0
# 1737  2016-12-29   977.10   997.95   974.55   986.05              555233.0
# 1738  2016-12-30   986.00  1006.95   985.90  1000.60              460675.0
#
#       Turnover (Lacs)
# 0             1157.18
# ...

# %%
data1['High'].unique()
# Out:
# array([1151.  , 1149.  , 1164.25, ...,  989.  ,  985.  ,  997.95])

# %%
data1['High'].nunique()
# Out:
# 1487

# %%
data2=data1.copy()

# %%
data2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1734    False
# 1735    False
# 1736    False
# 1737    False
# 1738    False
# Length: 1739, dtype: bool

# %%
data2[data2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Last, Close, Total Trade Quantity, Turnover (Lacs)]
# Index: []

# %%
data2.drop_duplicates()
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
data2.rename(columns={'Close':'Closes'},inplace=True)

# %%
data2.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Closes', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %% [markdown]
# # handle null values

# %%
data2.fillna({
    'high':data2['Closes'].mean(),
    })
# Out:
#             Date     Open     High      Low     Last   Closes  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
data2.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Closes                  0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
data2.dropna(inplace=True)

# %%
data2.shape
# Out:
# (1739, 8)

# %%
sns.catplot(data=data2,kind='box')
plt.show()

# %%
data2['Total Trade Quantity'].describe()
# Out:
# count    1.739000e+03
# mean     2.352309e+05
# std      3.561114e+05
# min      2.441000e+03
# 25%      5.878150e+04
# 50%      1.282050e+05
# 75%      2.513440e+05
# max      3.720854e+06
# Name: Total Trade Quantity, dtype: float64

# %%
Q1=data2['Total Trade Quantity'].quantile(0.25)
Q3=data2['Total Trade Quantity'].quantile(0.5)
IQR=Q1-Q3

# %%
Q1,Q3,IQR
# Out:
# (58781.5, 128205.0, -69423.5)

# %%
ulimit = Q3 + 1.5 * IQR
llimit = Q1 - 1.5 * IQR
ulimit, llimit
# Out:
# (24069.75, 162916.75)

# %%
data2['Total Trade Quantity'].apply(lambda x:ulimit if x>ulimit else x)
# Out:
# 0       24069.75
# 1       24069.75
# 2       24069.75
# 3       24069.75
# 4       24069.75
#           ...
# 1734    24069.75
# 1735    24069.75
# 1736    24069.75
# 1737    24069.75
# 1738    24069.75
# Name: Total Trade Quantity, Length: 1739, dtype: float64

# %%
data2['Total Trade Quantity_4']=data2['Total Trade Quantity'].apply(lambda x:ulimit if x>ulimit else x)

# %%
data2
# Out:
#             Date     Open     High      Low     Last   Closes  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)  Total Trade Quantity_4
# 0                 101651.0          1157.18                24069.75
# 1                  59504.0           676.47                24069.75
# ...

# %%
sns.heatmap(data2.isnull())
plt.show()
